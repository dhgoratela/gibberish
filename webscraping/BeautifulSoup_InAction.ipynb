# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website = "https://www.cars.com/shopping/results/?stock_type=all&makes%5B%5D=lamborghini&models%5B%5D=&list_price_max=&maximum_distance=20&zip="

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website)

# %% [markdown]
# #### Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">New and used Lamborghini for Sale Near Me | Cars.com</title>
# <meta content="Shop Lamborghini vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 680 Lamborghini models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="New and used Lamborghini for Sale Near Me | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results/" property="og:url"/>
# <meta content="Shop Lamborghini vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 680 Lamborghini models nationwide." property="og:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="New and used Lamborghini for Sale Near Me | Cars.com" name="twitter:title"/>
# <meta content="Shop Lamborghini vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 680 Lamborghini models nationwide." name="twitter:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" name="twitter:image"/>
# <script type="application/ld+json">{"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}</script>
# <style>
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font-weight:400;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{position:relative;display:inline}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;width:20px;left:0;opacity:0;position:absolute;top:0}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{content:"";position:absolute;top:-.1em;left:0;height:20px;width:20px;border:1px solid #bdbdbd}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{opacity:.4;cursor:not-allowed}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{content:"";border:3px solid #000;border-left:0;border-top:0;height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{padding:0 0 0 32px;margin:0;position:relative;cursor:pointer}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media (-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;width:100%;height:100%}*,:after,:before{box-sizing:inherit;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:g ...
#
#       </style>
# <style>
# .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{display:flex;justify-content:space-between;align-items:center;min-height:48px;height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;justify-content:space-between;flex-direction:row}.active-filter-tags .flex-container .show-more-less{display:flex;justify-content:flex-start;align-content:flex-end;flex-direction:row;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{margin-top:5px;margin-left:5px;stroke:#b0c!important}.active-filter-tags .flex-container .show-more-less span{cursor:pointer;color:#b0c}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{cursor:pointer;color:#b0c}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}.branded-canvas{position:relative;height:504px;width:100%;margin-bottom:24px;box-shadow:inset 0 -1px 0 0 #e6e6e6;border:1px solid #e6e6e6}@media (min-width:768px){.branded-canvas{height:343px}}@media (min-width:980px){.branded-canvas{height:343px}}.branded-canvas .branded-canvas-main-container{display:flex;position:relative;width:100%;height:278px;overflow:hidden;flex-direction:column}@media (min-width:768px){.branded-canvas .branded-canvas-main-container{flex-direction:row;justify-content:space-between;height:265px}}.branded-canvas .branded-canvas-main-container .branded-canvas-from{position:absolute;z-index:1;top:32px;color:#fff;font-size:11px;font-style:italic;left:10px}.branded-canvas .branded-canvas-main-container .branded-canvas-logo{position:absolute;top:10px;right:12px;height:55px;width:55px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{position:relative;flex:0 0 45%;height:175px;text-align:center;z-index:1}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 50%}}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{max-width:280px;position:inherit;padding-top:52px}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{position:absolute;max-width:80%;top:30%;left:11%;padding-top:0}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:none}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:flex;justify-content:end}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense:hover .sds-text-field__icon_1{stroke:#fff;transition:stroke .25s ease}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1{padding:8px;margin:16px 8px 16px 0;flex:1 1 50%;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1 .sds-text-field__icon{stroke:#532380;margin-left:4px}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2{padding:8px;margin:16px 16px 16px 0;flex:1 1 50%;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2 .sds-text-field__icon{stroke:#fff;margin-left:4px}.branded-canvas .branded-canvas-news{display:block;border-top:1px solid #e6e6e6;flex-direction:column}@media (min-width:768px){.branded-canvas .branded-canvas-ne ...
#
#           </style>
# <script defer="" src="/2c5fbfc8980b62dab924/js/app.js?vsn=d"></script>
# <script id="datadog-config" type="application/json">
#     {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "sampleRate": 5,
#         "trackInteractions": true
#     }
# </script>
# <script id="datadog-global-context" type="application/json">
# {"env":"production","trip_id":""}
# </script>
# <script>
#   window.Sentry = {"dsn":"https://d87f578bcce44b39bf79b9bafe713552@sentry.io/1809010","environment_name":"prod","included_environments":["prod","prod"],"release":"ffb5837a67cab826923852da66d04ff1f3cdac53","whitelistUrls":["https://www.cars.com","https://www.beta-cars.com"]}
# </script>
# <meta charset="utf-8" content="DjMCPg4EAyoMI3QoJVJYBzoXAEp7fkcNxbzI6L0H5qG_djoLHPr2CH3l" csrf-param="_csrf_token" method-param="_method" name="csrf-token"/>
# </head>
# <body>
# <div class="global-header-container">
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/"><img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/></a>
# <nav class="">
# <button aria-controls="mobile-menu-section" aria-expanded="false" class="mobile-nav-menu-button" id="mobile-menu-button">
# <div class="mobile-nav-menu-open">
# <svg class="menu-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#menu"></use></svg>
# <span>Menu</span>
# </div>
# <div class="mobile-nav-menu-close hidden">
# <svg class="close-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# <span>Close</span>
# </div>
# </button>
# <div aria-labelledby="mobile-menu-button" class="global-header-menu-links" id="mobile-menu-section">
# <ul class="header-links-wrapper">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <div class="sign-in-up-out mobile">
# <a class="header-signin" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dlamborghini%26maximum_distance%3D20%26models%255B%255D%3D%26stock_type%3Dall%26zip%3D">Sign In</a>
# <span class="sign-in-out-divider">/</span>
# <a class="header-signup" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dlamborghini%26maximum_distance%3D20%26models%255B%255D%3D%26stock_type%3Dall%26zip%3D">Sign Up</a>
# </div>
# </div>
# </nav>
# </section>
# </header>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here"></div>
# <div data-phx-main="true" data-phx-session="SFMyNTY.....Z2Pv-tmaBeHIfSKzuF-gotht-yzzJ8kiN41xe4IirSk" data-phx-static="SFMyNTY.g2gDaAJhBHQAAAADZAAKYXNzaWduX25ld2wAAAACZAANaXNfc2VhcmNoX2JvdGQADGN1cnJlbnRfdXNlcmpkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GcXhpZ1pkZnl0QnI1ejJpbgYAKNlqZXwBYgABUYA.YwLvSo45HGgQEbojC0kBWz8O78tY7npcxEJ_s5rFNPA" data-phx-view="Listing.SearchLive" id="phx-FqxigZdfytBr5z2i">
# <link as="image" href="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/iB4MThYYDDRxUdVBJMBgtO1g8LQ.jpg" rel="preload"/>
# <section class="sds-page-section search-live" id="search-live-container">
# <div class="display-ad" data-ad-sizes="[[970, 90], [728, 90], [970, 250], [320, 50]]" data-ad-type="full-page-width" data-ad-unit-path="6427/shop/mix.srp/top" data-appnexus-placement-id="17848514" data-hidden-on="" id="srp-top" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-srp-top" phx-update="ignore"></div>
# </div>
# </section>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="srp-lead-form-modal" phx-hook="ModalBackdrop" phx-target="#srp-lead-form-modal">
# <div class="sds-modal__content" phx-click="close" phx-target="#srp-lead-form-modal" phx-value-close="false">
# <div class="sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#srp-lead-form-modal" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="sds-modal__content-body">
# </div>
# </div>
# </div>
# <div phx-hook="LeadSubmissionTracker" phx_value_cid="srp-lead-form-modal"></div>
# <div phx-hook="LeadFormPositionAdjustments"></div>
# <div id="auth-completion-listener" phx-hook="AuthCompletionListener"></div>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one" data-activity-rule-type="custom" data-analytics-linkname="profiles-modal-close" data-component="profiles-modal" data-hook-callback="close_modal" id="auth-modal" phx-hook="ModalBackdrop" phx-target="#auth-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head">
# <div class="sds-icon--target btn-close" data-activity-rule-type="custom" data-component="profiles-modal" data-linkname="profiles-modal-close" phx-click="close_modal" phx-target="#auth-modal" role="button">
# <span class="sds-icon">
# <svg height="24" width="24"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="sds-modal__content-body">
# <div class="sign-up">
# <h3 class="sds-heading--3 sds-heading--display sds-page-section__title">Create your account</h3>
# <div class="modal-body">
# <p class="sds-page-section__title--sub">
# Sign up access your saved searches anywhere, anytime, and from any device.
#     </p>
# <p class="sds-page-section__title--sub">
# Already have a profile? <a data-activity-rule-type="custom" data-component="profiles-modal" data-linkname="modal-sign-in" href="#" phx-click="sign_in" phx-target="#auth-modal">Sign in</a>.
#     </p>
# <ul class="sds-list social-link-list">
# <li class="social-link">
# <a class="sds-button facebook-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-facebook" href="/signin/fb_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dlamborghini%26maximum_distance%3D20%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dfacebook%26stock_type%3Dall%26zip%3D">
# <svg class="facebook-svg-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#facebook"></use></svg>Sign in with Facebook
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button google-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/google_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dlamborghini%26maximum_distance%3D20%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dgoogle%26stock_type%3Dall%26zip%3D">
# <svg fill="none" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M28.48 16.2955C28.48 15.3736 28.3973 14.4873 28.2436 13.6364H16V18.665H22.9964C22.695 20.29 21.7791 21.6668 20.4023 22.5886V25.8505H24.6036C27.0618 23.5873 28.48 20.2545 28.48 16.2955Z" fill="#4285F4" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 29C19.51 29 22.4527 27.8359 24.6036 25.8505L20.4023 22.5886C19.2382 23.3686 17.7491 23.8295 16 23.8295C12.6141 23.8295 9.74819 21.5427 8.72592 18.47H4.38274V21.8382C6.52183 26.0868 10.9182 29 16 29Z" fill="#34A853" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M8.72591 18.47C8.46591 17.69 8.31818 16.8568 8.31818 16C8.31818 15.1432 8.46591 14.31 8.72591 13.53V10.1618H4.38273C3.50227 11.9168 3 13.9023 3 16C3 18.0977 3.50227 20.0832 4.38273 21.8382L8.72591 18.47Z" fill="#FBBC05" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 8.17045C17.9086 8.17045 19.6223 8.82636 20.9696 10.1145L24.6982 6.38591C22.4468 4.28818 19.5041 3 16 3C10.9182 3 6.52183 5.91318 4.38274 10.1618L8.72592 13.53C9.74819 10.4573 12.6141 8.17045 16 8.17045Z" fill="#EA4335" fill-rule="evenodd"></path>
# </svg>
#   Sign in with Google
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button apple-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-apple" href="/signin/apple_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dlamborghini%26maximum_distance%3D20%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dapple%26stock_type%3Dall%26zip%3D">
# <svg height="44px" version="1.1" viewbox="0 -2 31 44" width="28px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Apple logo</title>
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <path d="M15.7099491,14.8846154 C16.5675461,14.8846154 17.642562,14.3048315 18.28274,13.5317864 C18.8625238,12.8312142 19.2852829,11.852829 19.2852829,10.8744437 C19.2852829,10.7415766 19.2732041,10.6087095 19.2490464,10.5 C18.2948188,10.5362365 17.1473299,11.140178 16.4588366,11.9494596 C15.9152893,12.56548 15.4200572,13.5317864 15.4200572,14.5222505 C15.4200572,14.6671964 15.4442149,14.8121424 15.4562937,14.8604577 C15.5166879,14.8725366 15.6133185,14.8846154 15.7099491,14.8846154 Z M12.6902416,29.5 C13.8618881,29.5 14.3812778,28.714876 15.8428163,28.714876 C17.3285124,28.714876 17.6546408,29.4758423 18.9591545,29.4758423 C20.2395105,29.4758423 21.0971074,28.292117 21.9063891,27.1325493 C22.8123013,25.8038779 23.1867451,24.4993643 23.2109027,24.4389701 C23.1263509,24.4148125 20.6743484,23.4122695 20.6743484,20.5979021 C20.6743484,18.1579784 22.6069612,17.0588048 22.7156707,16.974253 C21.4353147,15.1382708 19.490623,15.0899555 18.9591545,15.0899555 C17.5217737,15.0899555 16.3501271,15.9596313 15.6133185,15.9596313 C14.8161157,15.9596313 13.7652575,15.1382708 12.521138,15.1382708 C10.1536872,15.1382708 7.75,17.0950413 7.75,20.7911634 C7.75,23.0861411 8.64383344,25.513986 9.74300699,27.0842339 C10.6851558,28.4129053 11.5065162,29.5 12.6902416,29.5 Z" fill="#FFFFFF" fill-rule="nonzero" id=""></path>
# </g>
# </svg>
#   Sign in with Apple
# </a>
# </li>
# </ul>
# <div class="separator-wrapper">
# <div class="sds-separator"></div>
# <div class="separator-text">Or</div>
# <div class="sds-separator"></div>
# </div>
# <form action="#" method="post" phx-submit="sign_up_continue" phx-target="#auth-modal"><input name="_csrf_token" type="hidden" value="DjMCPg4EAyoMI3QoJVJYBzoXAEp7fkcNxbzI6L0H5qG_djoLHPr2CH3l"/>
# <div class="sds-field-group">
# <div class="sds-field email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="account" id="user_email" maxlength="255" name="user[email]" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="user_email">Email</label>
# </div>
# </div>
# </div>
# <div class="actions">
# <div class="sds-field">
# <button class="sds-button" type="submit">Continue</button>
# </div>
# </div>
# </form>
# <div class="disclaimer">
# <div class="sds-disclaimer">
# By signing up, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
#    and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-page-section listings-page" data-applied-filter-criteria="" data-liveview-pageview="true" data-premier-dealer-search="no_premier_dealer_found" data-props='{"selected_refinement":null}' data-search-instance-id="60696eaf-87fd-45ee-ad7a-66413dccfc00" data-search-type="general-inventory-search" data-site-activity='{"search_results_on_page":20,"search_zip":"","model_group":null,"vehicleArray":[{"badges":["fair_deal","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Lamborghini:Urus:","cat":"luxurysuv_crossover","certified_preowned":false,"cpo_indicator":false,"customer_id":"165635","exterior_color":null,"fuel_type":"Gasoline","listing_id":"9f0a6376-599c-46f5-9436-e4cfaf023466","make":"Lamborghini","mileage":"2500","model":"Urus","msrp":null,"price":"299000","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":null,"vin":"ZPBUA1ZL4MLA12232","year":"2021"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Lamborghini:Urus:","cat":"luxurysuv_crossover","certified_preowned":false,"cpo_indicator":false,"customer_id":"177262","exterior_color":null,"fuel_type":"Gasoline","listing_id":"84ca06ce-d6c0-4301-927d-2fea54ea87cb","make":"Lamborghini","mileage":"1183","model":"Urus","msrp":null,"price":"349999","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":null,"vin":"ZPBUA1ZL7MLA14802","year":"2021"},{"badges":["fair_deal","virtual_appt","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Lamborghini:Urus:","cat":"luxurysuv_crossover","certified_preowned":false,"cpo_indicator":false,"customer_id":"5379308","exterior_color":null,"fuel_type":"Gasoline","listing_id":"06796cce-7910-4c37-b203-4e5e720c7000","make":"Lamborghini","mileage":"6159","model":"Urus","msrp":null,"price":"304990","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":null,"vin":"ZPBUA1ZL4MLA12070","year":"2021"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Lamborghini:Urus:Base","cat":"luxurysuv_crossover","certified_preowned":false,"cpo_indicator":false,"customer_id":"5386454","exterior_color":null,"fuel_type":"Gasoline","listing_id":"06394e08-c658-42c0-b688-88815d0f3311","make":"Lamborghini","mileage":"13486","model":"Urus","msrp":null,"price":"259895","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":"Base","vin":"ZPBUA1ZL1KLA00911","year":"2019"},{"badges":["virtual_appt","price_drop_in_cents","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Lamborghini:Urus:Base","cat":"luxurysuv_crossover","certified_preowned":false,"cpo_indicator":false,"customer_id":"113984","exterior_color":null,"fuel_type":"Gasoline","listing_id":"2aa04baf-6acb-4b92-8d74-7abd333b87ce","make":"Lamborghini","mileage":"18001","model":"Urus","msrp":null,"price":"258800","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":"Base","vin":"ZPBUA1ZL8KLA03630","year":"2019"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"Coupe","canonical_mmt":"Lamborghini:Huracan EVO:Base","cat":"sportscar_standard","certified_preowned":false,"cpo_indicator":false,"customer_id":"5383761","exterior_color":null,"fuel_type":"Gasoline","listing_id":"fdedf3dc-b141-4160-8d4b-5a539093391e","make":"Lamborghini","mileage":"15730","model":"Huracan EVO","msrp":null,"price":"294900","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":"Base","vin":"ZHWUF4ZF3LLA13885","year":"2020"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Lamborghini:Urus:Base","cat":"luxurysuv_crossover","certified_preowned":false,"cpo_indicator":false,"customer_id":"5363142","exterior_color":null,"fuel_type":"Gasoline","listing_id":"dab67649-0dee-4ab4-8499-22fc9d1400ec","make":"Lamborghini","mileage":"23513","model":"Urus","msrp":null,"price":"249995","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim" ...
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","name":"2021 Lamborghini Urus ","position":1,"url":"https://www.cars.com/vehicledetail/9f0a6376-599c-46f5-9436-e4cfaf023466/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=0/"},{"@type":"ListItem","name":"2021 Lamborghini Urus ","position":2,"url":"https://www.cars.com/vehicledetail/84ca06ce-d6c0-4301-927d-2fea54ea87cb/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=1/"},{"@type":"ListItem","name":"2021 Lamborghini Urus ","position":3,"url":"https://www.cars.com/vehicledetail/06796cce-7910-4c37-b203-4e5e720c7000/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=2/"},{"@type":"ListItem","name":"2019 Lamborghini Urus Base","position":4,"url":"https://www.cars.com/vehicledetail/06394e08-c658-42c0-b688-88815d0f3311/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=3/"},{"@type":"ListItem","name":"2019 Lamborghini Urus Base","position":5,"url":"https://www.cars.com/vehicledetail/2aa04baf-6acb-4b92-8d74-7abd333b87ce/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=4/"},{"@type":"ListItem","name":"2020 Lamborghini Huracan EVO Base","position":6,"url":"https://www.cars.com/vehicledetail/fdedf3dc-b141-4160-8d4b-5a539093391e/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=5/"},{"@type":"ListItem","name":"2019 Lamborghini Urus Base","position":7,"url":"https://www.cars.com/vehicledetail/dab67649-0dee-4ab4-8499-22fc9d1400ec/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=6/"},{"@type":"ListItem","name":"2017 Lamborghini Huracan LP610-4S","position":8,"url":"https://www.cars.com/vehicledetail/52060470-da79-4b3d-b005-25499face628/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=7/"},{"@type":"ListItem","name":"2020 Lamborghini Urus Base","position":9,"url":"https://www.cars.com/vehicledetail/4bca2a40-95b0-41dd-aeb8-362fb4e4e44e/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=8/"},{"@type":"ListItem","name":"2021 Lamborghini Urus HUGE MSRP! LOADED! FULL PPF! RARE PAINT! AKRAPOVIC","position":10,"url":"https://www.cars.com/vehicledetail/592092a8-228f-4b93-a6a1-ec7a797e3e46/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=9/"},{"@type":"ListItem","name":"2012 Lamborghini Gallardo LP550-2","position":11,"url":"https://www.cars.com/vehicledetail/97932edd-df85-4c32-a71a-cbda3e387910/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=10/"},{"@type":"ListItem","name":"2019 Lamborghini Urus Base","position":12,"url":"https://www.cars.com/vehicledetail/a1bdd6bd-e1fb-4e3e-bb2f-27159d92cd40/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=11/"},{"@type":"ListItem","name":"2019 Lamborghini Urus Base","position":13,"url":"https://www.cars.com/vehicledetail/0a34c586-a0d8-4cdb-ad2d-b02e29701e65/?results_page_number=1&search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&search_zipcode=&sponsored%3F=false&vertical_position=12/"},{"@type":"ListItem","name":"2017 Lamborghini Huracan LP580-2S","position":14,"url":"https://www.cars.com/vehicledetail/c77c0328- ...
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/iB4MThYYDDRxUdVBJMBgtO1g8LQ.jpg"},"name":"2021 Lamborghini Urus","vehicleIdentificationNumber":"ZPBUA1ZL4MLA12232"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/f7e3d89d-c385-5c36-81f1-9d6ac9079303/f8e0b49d-bdd0-41bd-a03d-29cbc846fcee/6iwu91a29bexrffjwXf-N71M4L4.jpg"},"name":"2021 Lamborghini Urus","vehicleIdentificationNumber":"ZPBUA1ZL7MLA14802"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/7439e0cd-f2eb-5669-aa84-442a17a88991/a19b3609-c8d7-4fc0-8b93-2f02493cc344/RJc3UMbltdOSAf3-bCYMC3am4sM.jpg"},"name":"2021 Lamborghini Urus","vehicleIdentificationNumber":"ZPBUA1ZL4MLA12070"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/4c8e17bc-b463-5ae1-9fb7-e0fbd0ac54cd/25fa7667-bef3-46df-8cab-d46a42791b5e/w9OzaTKSzqcJbtdLR1Nd56c57xg.jpg"},"name":"2019 Lamborghini Urus","vehicleIdentificationNumber":"ZPBUA1ZL1KLA00911"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/08cb8b0e-0d9b-5eba-9354-55618dd089a2/4984b319-3607-4d11-a235-39317fa5aa4d/Kma2bnH0opljds0BWhmM5XL9kBc.jpg"},"name":"2019 Lamborghini Urus","vehicleIdentificationNumber":"ZPBUA1ZL8KLA03630"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/56a8452e-c1e5-5c6b-8671-024e77bdc075/36066e4a-4781-4579-a9eb-a34a8bbaf1a4/e3UB5ocu6L0TDKFVjR1L_NlVmZE.jpg"},"name":"2020 Lamborghini Huracan EVO","vehicleIdentificationNumber":"ZHWUF4ZF3LLA13885"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/9e58300d-1952-534e-886d-004b8ae6913b/b13f4724-dbc1-4dda-8c92-28afda7d3bfe/KSktJKNhnYEISOXBjkvv1P6e2NM.jpg"},"name":"2019 Lamborghini Urus","vehicleIdentificationNumber":"ZPBUA1ZL0KLA01015"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/65e7a480-67ae-5868-9139-cb0dc1eb6a7b/02654abf-df89-4bad-b703-52ff2d8446e0/EfstDUOOYy9ZepZDTw5ev1ucJg0.jpg"},"name":"2017 Lamborghini Huracan","vehicleIdentificationNumber":"ZHWUR1ZF2HLA06858"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/3a4cc73e-9cfd-5ddc-99f6-19e642b98d47/08390929-0022-4fd6-aab9-6d8e149c7f2d/8Zs5pN75W5ghCOupCfu-ktwM_wY.jpg"},"name":"2020 Lamborghini Urus","vehicleIdentificationNumber":"ZPBUA1ZL9LLA08689"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Lamborghini"},"image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-image ...
# <script type="application/ld+json">{"@context":"http://schema.org/","@type":"AggregateOffer","availability":"http://schema.org/InStock","highPrice":359800,"lowPrice":179900,"priceCurrency":"USD"}</script>
# <nav class="search-filter-bar">
# <button class="" data-activity-rule-type="custom" data-component="save-search-sign-up" data-linkname="save-search-sign-up" id="search_filter_bar_save_search_button" phx-click="save_search" phx-target="#saved_search">
#   Save search
# </button>
# <button phx-click="show_sort_overlay">
# Sort
#     </button>
# <button id="show-search-form-overlay" phx-click="show_search_form_overlay" phx-hook="ShowSearchFormOverlay">
# Filter
#     </button>
# </nav>
# <header class="sds-page-section__header">
# <nav aria-label="breadcrumb">
# <ul class="sds-breadcrumb sds-breadcrumb--mobile-custom">
# <li class="sds-breadcrumb__parent">
# <span class="sds-icon">
# <svg aria-describedby="description" aria-labelledby="title" fill="none" height="16" role="img" stroke="#000000" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
# <title id="title">arrow-left</title>
# <desc id="description">An arrow pointing left.</desc>
# <path d="M19 12H6M12 5l-7 7 7 7"></path></svg>
# </span>
# <span><a data-component="breadcrumb" data-linkname="Home" href="/">Home</a></span>
# </li>
# <li aria-current="page">Cars for Sale</li>
# </ul>
# </nav>
# <script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","item":{"@id":"https://www.cars.com/","name":"Home"},"position":1},{"@type":"ListItem","item":{"@id":"https://www.cars.com/shopping/","name":"Cars for Sale"},"position":2}]}
# </script>
# <div class="heading-container">
# <h1 class="sds-heading--1 sds-page-section__title">New and used Lamborghini for sale</h1>
# <form action="#" class="sort-form" id="desktop_sort" method="post" phx-change="sort_form_change"><input name="_csrf_token" type="hidden" value="DjMCPg4EAyoMI3QoJVJYBzoXAEp7fkcNxbzI6L0H5qG_djoLHPr2CH3l"/>
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" data-activitykey="sort-dropdown" data-component="sort-apply" id="sort-dropdown" name="sort" phx-page-loading=""><option selected="" value="best_match_desc">Best match</option><option value="list_price">Lowest price</option><option value="list_price_desc">Highest price</option><option value="mileage">Lowest mileage</option><option value="mileage_desc">Highest mileage</option><option value="distance">Nearest location</option><option value="best_deal">Best deal</option><option value="year_desc">Newest year</option><option value="year">Oldest year</option><option value="listed_at_desc">Newest listed</option><option value="listed_at">Oldest listed</option></select>
# <label class="sds-label" for="sort-dropdown">Sort by</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </form>
# </div>
# <span class="total-entries">
# 680 matches
#       </span>
# </header>
# <div class="sds-page-section__content">
# <div class="vehicle-cards" data-tracking-orientation="vertical" id="vehicle-cards-container" phx-update="replace">
# <div class="save-search-banner">
# <div class="header">
# <svg aria-describedby="duotone-search_description" aria-labelledby="duotone-search_title" class="duotone search" role="img" viewbox="0 0 31 41" xmlns="http://www.w3.org/2000/svg">
# <title id="duotone-search_title">duotone-search</title>
# <desc id="duotone-search_description">A stylized magnifying glass.</desc>
# <polygon class="cls-1" fill="#250858" id="Rectangle" points="16.79 24.15 19.68 22.91 25.54 30.42 22.64 31.66 16.79 24.15"></polygon>
# <path class="cls-2" d="M24.39,27.5l6.15,10.33h0l-4.61,2.58L19.81,30.12a1,1,0,0,1,.35-1.37h0L23,27.14A1,1,0,0,1,24.39,27.5Z" fill="#00bfde" id="path-1"></path>
# <path class="cls-3" d="M6.87,1.84a13.75,13.75,0,1,1-5,18.79A13.76,13.76,0,0,1,6.87,1.84ZM8.75,5.09A10,10,0,1,0,22.41,8.75,10,10,0,0,0,8.75,5.09Z" fill="#532380" id="Combined-Shape"></path>
# </svg>
# <div class="message">
# <strong>Save your search</strong>
#  to easily start where you left off, get updates on new inventory &amp; price drops.
#             </div>
# </div>
# <button class="sds-button--secondary sds-button--dense" data-activity-rule-type="custom" data-component="save-search-sign-up" data-linkname="save-search-sign-up" id="banner_save_search_button" phx-click="save_search" phx-target="#saved_search">
#   Sign up
# </button>
# </div>
# <div class="vehicle-card" data-listing-id="9f0a6376-599c-46f5-9436-e4cfaf023466" data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="9f0a6376-599c-46f5-9436-e4cfaf023466" phx-hook="VehicleCard" phx-target="5">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/9f0a6376-599c-46f5-9436-e4cfaf023466/" rel="nofollow" tabindex="-1"></a>
# <div class="vehicle-card-main js-gallery-click-card">
# <div class="vehicle-card-photos js-gallery-click-gallery">
# <div class="gallery-wrap">
# <div class="image-wrap" data-index="0">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/iB4MThYYDDRxUdVBJMBgtO1g8LQ.jpg"/>
# </div>
# <div class="image-wrap" data-index="1">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/pDlOwdUC6waI0LJw7UR_t8o6jbw.jpg"/>
# </div>
# <div class="image-wrap" data-index="2">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/G88BxnRrLNRHsmCXbrVm1O3rjQk.jpg"/>
# </div>
# <div class="image-wrap" data-index="3">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/HVbUt4SKnPC4RC5vYn3jFYMluak.jpg"/>
# </div>
# <div class="image-wrap" data-index="4">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/H7qKrPNX0O5htZiCAOB_4C7KyB8.jpg"/>
# </div>
# <div class="image-wrap" data-index="5">
# <div class="gallery-view-all">
# <img alt="" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/pSSoUWTFTlXN4jxy_YITipuaXQc.jpg" src="/images/placeholder_10x10.png"/>
# <div class="sds-button sds-button--secondary-dense">View all 45 photos</div>
# </div>
# </div>
# </div>
# <button class="image-control-left">
# <div class="rectangle rectangle-left">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <button class="image-control-right">
# <div class="rectangle rectangle-right">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <div class="gallery-indicator"><span class="gallery-indicator-current-image">1</span>/45</div>
# <div class="gallery-nav">
# <div class="image-indicator selected"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# </div>
# </div>
# <div class="vehicle-details">
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-index="1" data-linkname="save-vehicle-sign-up" data-listing-id="9f0a6376-599c-46f5-9436-e4cfaf023466" id="vehicle-heart-1" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="83" phx-value-is_vdp="false" phx-value-listing_id="9f0a6376-599c-46f5-9436-e4cfaf023466">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">Used</p>
# <a class="vehicle-card-link js-gallery-click-link" data-activity-rule-type="page-over-page" data-linkname="vehicle-listing" href="/vehicledetail/9f0a6376-599c-46f5-9436-e4cfaf023466/?results_page_number=1&amp;search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&amp;search_zipcode=&amp;sponsored%3F=false&amp;vertical_position=1" rel="nofollow">
# <h2 class="title">2021 Lamborghini Urus </h2>
# </a>
# <div class="mileage">2,500 mi.</div>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$299,000</span>
# </div>
# <div class="vehicle-badging" data-click-intent-id="badges-explainer" data-contents="{&quot;home_delivery_badge&quot;:true,&quot;price_badge&quot;:{&quot;price_badge&quot;:&quot;similarly&quot;,&quot;price_badge_description&quot;:&quot;This car is fairly priced. Our analysis compares this car's price, features, and condition with similar 2021 Urus.&quot;,&quot;price_badge_savings_icon_text&quot;:&quot;&quot;,&quot;price_badge_text&quot;:&quot;Fair&quot;,&quot;price_badge_text_lowercase&quot;:&quot;fair&quot;,&quot;price_savings_text&quot;:&quot;&quot;,&quot;svg_tag&quot;:&quot;&lt;svg class=\&quot;sds-text-field__icon\&quot; height=\&quot;16\&quot; width=\&quot;16\&quot;&gt;&lt;use xlink:href=\&quot;/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-right-thick\&quot;&gt;&lt;/use&gt;&lt;/svg&gt;&quot;},&quot;href_to_vdp&quot;:{&quot;href_to_vdp&quot;:&quot;/vehicledetail/9f0a6376-599c-46f5-9436-e4cfaf023466/?bodystyle=suv&amp;cpo_indicator=false&amp;customer_id=165635&amp;intent_id=badges-explainer&amp;listing_id=9f0a6376-599c-46f5-9436-e4cfaf023466&amp;make=lamborghini&amp;model=urus&amp;model_year=2021&amp;msrp=&amp;price=299000&amp;sponsored%3F=false&amp;stock_type=used&amp;trim=&quot;}}" data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"165635","horizontal_position":null,"listing_id":"9f0a6376-599c-46f5-9436-e4cfaf023466","make":"lamborghini","model":"urus","model_year":"2021","msrp":null,"price":"299000","results_page_number":1,"sponsored?":false,"stock_type":"used","trim":null,"vertical_position":1,"web_page_type_from":"shopping/search-results"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div aria-label="price_badge" class="sds-badge sds-badge--icon sds-badge--fair js-price-badging" data-linkname="price-badge-fair">
# <div class="sds-badge__icon">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-right-thick"></use></svg>
# </div>
# <span class="sds-badge__label">Fair Deal<span class="sds-badge--price-savings"></span></span>
# </div>
# <div class="sds-badge sds-badge--home-delivery">
# <span class="sds-badge__label">Home Delivery</span>
# </div>
# </div>
# <div class="vehicle-links external-links">
# <div class="vehicle-deeplink">
# <a class="sds-link--ext" data-intent-id="srp-vehicle-history-report" data-linkname="vehicle-history" data-override-payload='{"page_url":"https://www.carfax.com/cfm/check_order.cfm?partner=CDC_1&amp;vin=ZPBUA1ZL4MLA12232"}' href="/external/carfax/?redirect=https%3A%2F%2Fwww.carfax.com%2Fcfm%2Fcheck_order.cfm%3Fpartner%3DCDC_1%26vin%3DZPBUA1ZL4MLA12232" rel="noopener nofollow" target="_blank">CARFAX Report<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a>
# </div>
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>Exotic Motors</strong>
# </div>
# <div class="sds-rating">
# <span class="sds-rating__count">4.4</span>
# <div class="sds-rating__wrapper">
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# ...
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Connect With Us</span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link"><a class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#twitter"></use></svg></a></li>
# <li class="social-link"><a class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#facebook"></use></svg></a></li>
# <li class="social-link"><a class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#youtube"></use></svg></a></li>
# <li class="social-link"><a class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#instagram"></use></svg></a></li>
# <li class="social-link"><a class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#linkedin"></use></svg></a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group accordion-group">
# <div aria-controls="footer-section-1" aria-expanded="false" class="accordion-header" id="footer-header-1" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Buying &amp; Selling</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-1" class="accordion-panel" hidden="" id="footer-section-1" role="region">
# <ul class="global-footer-list sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-buying-selling" data-component-index="1" data-linkname="footer-find-a-car" href="/shopping/">Find a Car</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-buying-selling" data-component-index="2" data-linkname="sitemap-city-listings" href="/sitemap/city-listings/">Listings by City</a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-group-stack">
# <div class="accordion-group footer-dealer-group">
# <div aria-controls="footer-section-2" aria-expanded="false" class="accordion-header" id="footer-header-2" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">For Dealers</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-2" class="accordion-panel" hidden="" id="footer-section-2" role="region">
# <ul class="global-footer-list sds-list">
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-linkname="footer-grow-with-cars" href="https://www.growwithcars.com" rel="noopener" target="_blank">Grow with CARS<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-linkname="footer-dealer-login" href="https://dealerdash.cars.com/" rel="noopener" target="_blank">Dealer Login<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# <div class="accordion-group">
# <div aria-controls="footer-section-3" aria-expanded="false" class="accordion-header" id="footer-header-3" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Explore Our Brand</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-3" class="accordion-panel" hidden="" id="footer-section-3" role="region">
# <ul class="global-footer-list sds-list">
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="1" data-linkname="footer-dealer-inspire" href="https://www.dealerinspire.com/" rel="noopener" target="_blank">Dealer Inspire<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="2" data-linkname="footer-dealerrater" href="https://www.dealerrater.com/" rel="noopener" target="_blank">DealerRater<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="3" data-linkname="footer-fuel" href="https://fuel.cars" rel="noopener" target="_blank">FUEL<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="4" data-linkname="footer-autocom" href="https://www.auto.com/" rel="noopener" target="_blank">Auto.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="5" data-linkname="footer-newcarscom" href="https://www.newcars.com/" rel="noopener" target="_blank">NewCars.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="6" data-linkname="footer-pickuptruckscom" href="https://www.pickuptrucks.com/" rel="noopener" target="_blank">Pickuptrucks.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-footer-group accordion-group">
# <div aria-controls="footer-section-4" aria-expanded="false" class="accordion-header" id="footer-header-4" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Our Company</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-4" class="accordion-panel" hidden="" id="footer-section-4" role="region">
# <ul class="global-footer-list sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="1" data-linkname="footer-about-cars" href="/about/">About Cars.com</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="2" data-linkname="footer-contact-cars" href="/contact/">Contact Cars.com</a></li>
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="3" data-linkname="footer-investor-relations" href="https://investor.cars.com/overview/default.aspx" rel="noopener" target="_blank">Investor Relations<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">Careers</a></li>
# <li><a class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">Licensing &amp; Reprints<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">Site Map</a></li>
# <li><a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">Feedback</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">Terms of Service</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">Privacy Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">Do Not Sell My Personal Information</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">Accessibility Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">Ad Choices</a></li>
# </ul>
# <div class="global-copyright-copy">©
# 2021 Cars.com. All rights reserved.</div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_afw2Gp67tcpDXi5" height="800px" width="600px"></iframe>
# </div>
# </div>
# </footer>
# <script src=""></script>
# <link data-href="/2c5fbfc8980b62dab924/css/common.css?vsn=d" media="print" rel="stylesheet">
# <link data-href="/2c5fbfc8980b62dab924/css/srp.css?vsn=d" media="print" rel="stylesheet"/>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"aff_code":"national","cat":null,"customer_id":"","designated_market_area_key":null,"lat_long":"/","local_zone":null,"loginStatus":false,"make":"","market_name":null,"marketing_click_data":null,"marketing_click_id":"","marketing_referral_source":"","model":"","page_channel":"shopping","page_detail":null,"page_key":"search-results","page_name":"shopping/search-results","page_type":"shopping/search-results","platform_id":"cars_responsive","profileAccountType":null,"trip_id":"","url_base":"","url_referer":"","useragent":"","utm_campaign":null,"utm_content":null,"utm_medium":null,"utm_source":null,"utm_term":null,"year":"","zip_ip2geo":null}
# </script>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"marketing_click_id":"","als_private_data":"QTEyOEdDTQ.bLKbn6CMcs5ObYQRtRVdZ3BHZtBhEWR6QO_gtAuo8-01Em8xN3Vb_RcHlpY.As3xnba5LGYSlfOQ.ppdkvSm1zfE-c74TQDbaHf2Irwo8-JVSFCm3gsFOTxsosNuHBl2QcLqu2ghPUbdVwEfXiIk.iOpHh0NK2_0xmDLTYHNsnA","device_os":null,"bodystyle":"","model_year":"","app_version":null,"results_page_count":34,"roxanne_visit_id":"","utm_medium":null,"horizontal_position":"","longitude":null,"is_bot":true,"referer_url":"","pdid":null,"carrier":null,"roxanne_visitor_id":"","utm_campaign":null,"trip_id":"","upsells":[],"utm_source":null,"incentive_ids":"","x_forwarded_for":null,"bot_type":"Unknown Bot (python-reque_B8E4201CA3B8EDF5DEAEE8E277BFB3CD):monitor:Behavior Anomaly;HTTP Libraries:100:aggressive","customer_id":"","make":"","cpo_indicator":true,"aff_code":"national","search_instance_id":null,"listing_id":"","platform_id":"cars_responsive","adobe_id":null,"stock_type":"","page_instance_id":"FqxigZc6UdLBa-cC9j2C","device_model":null,"latitude":null,"web_page_type_from":"","total_results":680,"device_id":null,"marketing_click_source":"","msrp":"","experiment_ids":"null","model":"","vertical_position":"","device_type":"desktop","profile_user_id":null,"utm_term":null,"useragent":"python-requests/2.26.0","page_url":"https://www.cars.com/shopping/results/?stock_type=all&amp;makes[]=lamborghini&amp;models[]=&amp;list_price_max=&amp;maximum_distance=20&amp;zip=","ga_client_id":null,"web_page_type_to":"shopping/search-results","timestamp_utc":1633789073756,"search_zipcode":"","results_page_number":1,"results_per_page":20,"utm_content":null,"internet_connection":null,"trim":"","price":null}
# </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
# </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js"></script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js"></script>
# <script>
#   window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#
#
# </script>
# <script src="/agjebJ/YIuQ/9HJ/Opu/yqM0uvT9ZZw/X5izbSJ2La/ZHFXenIRVwc/ZwQVR/SNGIh4B" type="text/javascript"></script></link></body>
# </html>

# %% [markdown]
# ### Results

# %%
results = soup.find_all('div', {'class': 'vehicle-card'})

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# <div class="vehicle-card" data-listing-id="9f0a6376-599c-46f5-9436-e4cfaf023466" data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="9f0a6376-599c-46f5-9436-e4cfaf023466" phx-hook="VehicleCard" phx-target="5">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/9f0a6376-599c-46f5-9436-e4cfaf023466/" rel="nofollow" tabindex="-1"></a>
# <div class="vehicle-card-main js-gallery-click-card">
# <div class="vehicle-card-photos js-gallery-click-gallery">
# <div class="gallery-wrap">
# <div class="image-wrap" data-index="0">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/iB4MThYYDDRxUdVBJMBgtO1g8LQ.jpg"/>
# </div>
# <div class="image-wrap" data-index="1">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/pDlOwdUC6waI0LJw7UR_t8o6jbw.jpg"/>
# </div>
# <div class="image-wrap" data-index="2">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/G88BxnRrLNRHsmCXbrVm1O3rjQk.jpg"/>
# </div>
# <div class="image-wrap" data-index="3">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/HVbUt4SKnPC4RC5vYn3jFYMluak.jpg"/>
# </div>
# <div class="image-wrap" data-index="4">
# <img alt="" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/H7qKrPNX0O5htZiCAOB_4C7KyB8.jpg"/>
# </div>
# <div class="image-wrap" data-index="5">
# <div class="gallery-view-all">
# <img alt="" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/0ed6601e-75f3-5b96-b8f7-10fecdc86520/ab41e310-26e4-48b6-a85e-46dad64f1e71/pSSoUWTFTlXN4jxy_YITipuaXQc.jpg" src="/images/placeholder_10x10.png"/>
# <div class="sds-button sds-button--secondary-dense">View all 45 photos</div>
# </div>
# </div>
# </div>
# <button class="image-control-left">
# <div class="rectangle rectangle-left">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <button class="image-control-right">
# <div class="rectangle rectangle-right">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <div class="gallery-indicator"><span class="gallery-indicator-current-image">1</span>/45</div>
# <div class="gallery-nav">
# <div class="image-indicator selected"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# </div>
# </div>
# <div class="vehicle-details">
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-index="1" data-linkname="save-vehicle-sign-up" data-listing-id="9f0a6376-599c-46f5-9436-e4cfaf023466" id="vehicle-heart-1" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="83" phx-value-is_vdp="false" phx-value-listing_id="9f0a6376-599c-46f5-9436-e4cfaf023466">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">Used</p>
# <a class="vehicle-card-link js-gallery-click-link" data-activity-rule-type="page-over-page" data-linkname="vehicle-listing" href="/vehicledetail/9f0a6376-599c-46f5-9436-e4cfaf023466/?results_page_number=1&amp;search_instance_id=60696eaf-87fd-45ee-ad7a-66413dccfc00&amp;search_zipcode=&amp;sponsored%3F=false&amp;vertical_position=1" rel="nofollow">
# <h2 class="title">2021 Lamborghini Urus </h2>
# </a>
# <div class="mileage">2,500 mi.</div>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$299,000</span>
# </div>
# <div class="vehicle-badging" data-click-intent-id="badges-explainer" data-contents="{&quot;home_delivery_badge&quot;:true,&quot;price_badge&quot;:{&quot;price_badge&quot;:&quot;similarly&quot;,&quot;price_badge_description&quot;:&quot;This car is fairly priced. Our analysis compares this car's price, features, and condition with similar 2021 Urus.&quot;,&quot;price_badge_savings_icon_text&quot;:&quot;&quot;,&quot;price_badge_text&quot;:&quot;Fair&quot;,&quot;price_badge_text_lowercase&quot;:&quot;fair&quot;,&quot;price_savings_text&quot;:&quot;&quot;,&quot;svg_tag&quot;:&quot;&lt;svg class=\&quot;sds-text-field__icon\&quot; height=\&quot;16\&quot; width=\&quot;16\&quot;&gt;&lt;use xlink:href=\&quot;/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-right-thick\&quot;&gt;&lt;/use&gt;&lt;/svg&gt;&quot;},&quot;href_to_vdp&quot;:{&quot;href_to_vdp&quot;:&quot;/vehicledetail/9f0a6376-599c-46f5-9436-e4cfaf023466/?bodystyle=suv&amp;cpo_indicator=false&amp;customer_id=165635&amp;intent_id=badges-explainer&amp;listing_id=9f0a6376-599c-46f5-9436-e4cfaf023466&amp;make=lamborghini&amp;model=urus&amp;model_year=2021&amp;msrp=&amp;price=299000&amp;sponsored%3F=false&amp;stock_type=used&amp;trim=&quot;}}" data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"165635","horizontal_position":null,"listing_id":"9f0a6376-599c-46f5-9436-e4cfaf023466","make":"lamborghini","model":"urus","model_year":"2021","msrp":null,"price":"299000","results_page_number":1,"sponsored?":false,"stock_type":"used","trim":null,"vertical_position":1,"web_page_type_from":"shopping/search-results"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div aria-label="price_badge" class="sds-badge sds-badge--icon sds-badge--fair js-price-badging" data-linkname="price-badge-fair">
# <div class="sds-badge__icon">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-right-thick"></use></svg>
# </div>
# <span class="sds-badge__label">Fair Deal<span class="sds-badge--price-savings"></span></span>
# </div>
# <div class="sds-badge sds-badge--home-delivery">
# <span class="sds-badge__label">Home Delivery</span>
# </div>
# </div>
# <div class="vehicle-links external-links">
# <div class="vehicle-deeplink">
# <a class="sds-link--ext" data-intent-id="srp-vehicle-history-report" data-linkname="vehicle-history" data-override-payload='{"page_url":"https://www.carfax.com/cfm/check_order.cfm?partner=CDC_1&amp;vin=ZPBUA1ZL4MLA12232"}' href="/external/carfax/?redirect=https%3A%2F%2Fwww.carfax.com%2Fcfm%2Fcheck_order.cfm%3Fpartner%3DCDC_1%26vin%3DZPBUA1ZL4MLA12232" rel="noopener nofollow" target="_blank">CARFAX Report<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a>
# </div>
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>Exotic Motors</strong>
# </div>
# <div class="sds-rating">
# <span class="sds-rating__count">4.4</span>
# <div class="sds-rating__wrapper">
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--half">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <defs>
# <lineargradient id="linear" x1="0%" x2="100%" y1="0%" y2="0%">
# <stop offset="0%" stop-color="#532380"></stop>
# <stop offset="50%" stop-color="#532380"></stop>
# <stop offset="50%" stop-color="transparent"></stop>
# <stop offset="100%" stop-color="transparent"></stop>
# </lineargradient>
# </defs>
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# </div>
# <span class="sds-rating__link sds-button-link">(568 reviews)</span>
# </div>
# <div class="miles-from hidden"> mi. from </div>
# </div>
# <div class="miles-from hidden"> mi. from </div>
# </div>
# <div class="contact-buttons" id="9f0a6376-599c-46f5-9436-e4cfaf023466-lead-btns">
# <a class="sds-button--secondary contact-by-phone" data-activity-rule-type="custom" data-call-intent-id="srp-call-intent" data-index="1" data-linkname="dealer-phone-srp" data-listing-id="9f0a6376-599c-46f5-9436-e4cfaf023466" data-make="Lamborghini" data-model="Urus" data-phone-number="8472414972" data-trim="" data-vin="ZPBUA1ZL4MLA12232" data-year="2021" href="tel:+1-847-241-4972" id="dealer-phone-1" phx-hook="CallSourceDniSRPCallButton" phx-update="ignore">Call</a>
# <button class="sds-button lead-form-modal-button" data-activity-rule-type="custom" data-dealer-customer-id="165635" data-index="1" data-linkname="email-lead-form-srp" data-listing-id="9f0a6376-599c-46f5-9436-e4cfaf023466" data-sponsored="false" data-sponsored-invariant="false" id="lead-form-email-9f0a6376-599c-46f5-9436-e4cfaf023466" phx-hook="ShowLeadForm">
#         Check availability
#       </button>
# <button class="sds-button lead-form-modal-button--desktop srp" data-activity-rule-type="custom" data-dealer-customer-id="165635" data-index="1" data-linkname="email-lead-form-srp" data-listing-id="9f0a6376-599c-46f5-9436-e4cfaf023466" data-sponsored="false" data-sponsored-invariant="false" id="lead-form-9f0a6376-599c-46f5-9436-e4cfaf023466" phx-hook="ShowLeadForm">
#         Check availability
#       </button>
# </div>
# </div>
# </div>

# %% [markdown]
# ### Target necessary data

# %%
# Name
# Price
# Review Rating
# Review Count
# Product Link
# Product Details

# %% [markdown]
# #### Name

# %%
results[0].find('h2').text.strip()
# Out:
# '2021 Lamborghini Urus'

# %% [markdown]
# #### Price

# %%
results[0].find('div', {'class':"mileage"}).text
# Out:
# '2,500 mi.'

# %% [markdown]
# #### Review Rating

# %%
results[0].find('span', {'class': 'sds-rating__count'}).text
# Out:
# '4.4'

# %% [markdown]
# #### Review Count

# %%
results[0].find('span', {'class': 'sds-rating__link sds-button-link'}).text
# Out:
# '(568 reviews)'

# %% [markdown]
# #### Price

# %%
results[0].find('span', {'class': 'primary-price'}).text
# Out:
# '$299,000'

# %% [markdown]
# #### Dealer name

# %%
results[0].find('div', {'class': 'dealer-name'}).text.strip()
# Out:
# 'Exotic Motors'

# %% [markdown]
# #### Relative URL

# %% [markdown]
# #### Product Details

# %% [markdown]
# ### Put everything together inside a For-Loop

# %%
class Custom:
    def add(list_name, data):
        try:
            list_name.append(data)
        except AttributeError:
            list_name.append('n/a')

# %%
name = []
mileage = []
dealer_name = []
rating = []
rating_count = []
price = []

for r in results:
    Custom.add(name, r.find('h2').text.strip())
    Custom.add(mileage, r.find('div', {'class':"mileage"}).text)
    Custom.add(rating_count, r.find('span', {'class': 'sds-rating__count'}).text)
    Custom.add(rating, r.find('span', {'class': 'sds-rating__link sds-button-link'}).text)
    Custom.add(price, r.find('span', {'class': 'primary-price'}).text)
    Custom.add(dealer_name, r.find('div', {'class': 'dealer-name'}).text.strip())

# %%
# name
# mileage
# rating_count
# rating
# price
# dealer_name
# Out:
# ['(568 reviews)',
#  '(15 reviews)',
#  '(5 reviews)',
#  '(3 reviews)',
#  '(692 reviews)',
#  '(7 reviews)',
#  '(64 reviews)',
#  '(620 reviews)',
#  '(3,697 reviews)',
#  '(629 reviews)',
#  '(27 reviews)',
#  '(136 reviews)',
#  '(4,514 reviews)',
#  '(84 reviews)',
#  '(58 reviews)',
#  '(1,239 reviews)',
#  '(9 reviews)',
#  '(41 reviews)',
#  '(1,239 reviews)',
#  '(73 reviews)']

# %% [markdown]
# #### Combine URLs

# %% [markdown]
# ### Create Pandas Dataframe

# %%
data = pd.DataFrame({'Name': name,
                     'Milage': mileage,
                     'DealerName': dealer_name,
                     'Rating': rating,
                     'RatingCount': rating_count,
                     'Price': price})

# %% [markdown]
# #### Data cleaning

# %%
data
# Out:
#                                                  Name      Milage  \
# 0                               2021 Lamborghini Urus   2,500 mi.
# 1                               2021 Lamborghini Urus   1,183 mi.
# 2                               2021 Lamborghini Urus   6,159 mi.
# 3                          2019 Lamborghini Urus Base  13,486 mi.
# 4                          2019 Lamborghini Urus Base  18,001 mi.
# 5                   2020 Lamborghini Huracan EVO Base  15,730 mi.
# 6                          2019 Lamborghini Urus Base  23,513 mi.
# 7                   2017 Lamborghini Huracan LP610-4S  15,352 mi.
# 8                          2020 Lamborghini Urus Base  23,797 mi.
# 9   2021 Lamborghini Urus HUGE MSRP! LOADED! FULL ...   7,700 mi.
# 10                  2012 Lamborghini Gallardo LP550-2   4,619 mi.
# 11                         2019 Lamborghini Urus Base  11,033 mi.
# 12                         2019 Lamborghini Urus Base  14,662 mi.
# 13                  2017 Lamborghini Huracan LP580-2S  21,349 mi.
# 14                              2020 Lamborghini Urus   6,082 mi.
# 15                         2019 Lamborghini Urus Base  31,338 mi.
# 16                         2020 Lamborghini Urus Base  17,522 mi.
# 17                           2015 Lamborghini Huracan  36,081 mi.
# 18                         2019 Lamborghini Urus Base  11,893 mi.
# 19                   2017 Lamborghini Huracan LP580-2   2,725 mi.
#
#                                            DealerName           Rating  \
# 0                                       Exotic Motors    (568 reviews)
# 1                                        Eurocar Inc.     (15 reviews)
# 2                          O'Gara Coach Beverly Hills      (5 reviews)
# 3                                    Pro Cars USA Inc      (3 reviews)
# 4                      Napleton Aston Martin Maserati    (692 reviews)
# 5                                      Tactical Fleet      (7 reviews)
# 6                                 Lamborghini Paramus     (64 reviews)
# 7                                    Honda Marysville    (620 reviews)
# 8                                      Audi San Diego  (3,697 reviews)
# 9                                  Chicago Motor Cars    (629 reviews)
# 10                                 UDrive Automobiles     (27 reviews)
# 11                                Auto Buying Service    (136 reviews)
# 12                 Motor Werks - Barrington Auto Mall  (4,514 reviews)
# 13                                       Auto Gallery     (84 reviews)
# 14                           Manhattan Motorcars Inc.     (58 reviews)
# 15                                Brooklyn Mitsubishi  (1,239 reviews)
# 16  Genesis, Alfa Romeo, Bentley, Maserati, Rolls-...      (9 reviews)
# 17                                South Bay Pre-Owned     (41 reviews)
# 18                                Brooklyn Mitsubishi  (1,239 reviews)
# 19                              Perillo Downers Grove     (73 reviews)
#
#    RatingCount     Price
# 0          4.4  $299,000
# 1          5.0  $349,999
# 2          2.6  $304,990
# 3          5.0  $259,895
# 4          4.7  $258,800
# 5          5.0  $294,900
# 6          5.0  $249,995
# 7          4.8  $254,997
# 8          4.7  $263,890
# 9          4.8  $359,800
# 10         4.8  $179,900
# 11         4.8  $268,995
# 12         4.8  $269,900
# 13         3.0  $229,995
# 14         4.6  $289,900
# 15         4.6  $265,001
# 16         3.6  $276,990
# 17         3.4  $199,995
# 18         4.6  $261,999
# 19         4.6  $246,818

# %%
data['Rating'] = data['Rating'].apply(lambda x: x.strip("(reviews) "))
data['Milage'] = data['Milage'].apply(lambda x: x.strip(" mi."))
data['Price'] = data['Price'].apply(lambda x: x.strip("$ "))

# %%
data
# Out:
#                                                  Name  Milage  \
# 0                               2021 Lamborghini Urus   2,500
# 1                               2021 Lamborghini Urus   1,183
# 2                               2021 Lamborghini Urus   6,159
# 3                          2019 Lamborghini Urus Base  13,486
# 4                          2019 Lamborghini Urus Base  18,001
# 5                   2020 Lamborghini Huracan EVO Base  15,730
# 6                          2019 Lamborghini Urus Base  23,513
# 7                   2017 Lamborghini Huracan LP610-4S  15,352
# 8                          2020 Lamborghini Urus Base  23,797
# 9   2021 Lamborghini Urus HUGE MSRP! LOADED! FULL ...   7,700
# 10                  2012 Lamborghini Gallardo LP550-2   4,619
# 11                         2019 Lamborghini Urus Base  11,033
# 12                         2019 Lamborghini Urus Base  14,662
# 13                  2017 Lamborghini Huracan LP580-2S  21,349
# 14                              2020 Lamborghini Urus   6,082
# 15                         2019 Lamborghini Urus Base  31,338
# 16                         2020 Lamborghini Urus Base  17,522
# 17                           2015 Lamborghini Huracan  36,081
# 18                         2019 Lamborghini Urus Base  11,893
# 19                   2017 Lamborghini Huracan LP580-2   2,725
#
#                                            DealerName Rating RatingCount  \
# 0                                       Exotic Motors    568         4.4
# 1                                        Eurocar Inc.     15         5.0
# 2                          O'Gara Coach Beverly Hills      5         2.6
# 3                                    Pro Cars USA Inc      3         5.0
# 4                      Napleton Aston Martin Maserati    692         4.7
# 5                                      Tactical Fleet      7         5.0
# 6                                 Lamborghini Paramus     64         5.0
# 7                                    Honda Marysville    620         4.8
# 8                                      Audi San Diego  3,697         4.7
# 9                                  Chicago Motor Cars    629         4.8
# 10                                 UDrive Automobiles     27         4.8
# 11                                Auto Buying Service    136         4.8
# 12                 Motor Werks - Barrington Auto Mall  4,514         4.8
# 13                                       Auto Gallery     84         3.0
# 14                           Manhattan Motorcars Inc.     58         4.6
# 15                                Brooklyn Mitsubishi  1,239         4.6
# 16  Genesis, Alfa Romeo, Bentley, Maserati, Rolls-...      9         3.6
# 17                                South Bay Pre-Owned     41         3.4
# 18                                Brooklyn Mitsubishi  1,239         4.6
# 19                              Perillo Downers Grove     73         4.6
#
#       Price
# 0   299,000
# 1   349,999
# 2   304,990
# 3   259,895
# 4   258,800
# 5   294,900
# 6   249,995
# 7   254,997
# 8   263,890
# 9   359,800
# 10  179,900
# 11  268,995
# 12  269,900
# 13  229,995
# 14  289,900
# 15  265,001
# 16  276,990
# 17  199,995
# 18  261,999
# 19  246,818

# %% [markdown]
# ### Output in Excel

# %%
data.to_excel('cars.xlsx', index=False)

# %% [markdown]
# ### Part 2 - Pagination - Scrape 20 Pages

# %%
class Custom:
    def add(list_name, data):
        try:
            list_name.append(data.text.strip())
        except AttributeError:
            list_name.append('n/a')

name = []
mileage = []
dealer_name = []
rating = []
rating_count = []
price = []

for i in range(1, 11):
    website = f'https://www.cars.com/shopping/results/?page={i}&page_size=20&dealer_id=&keyword=&list_price_max=&list_price_min=&makes[]=lamborghini&maximum_distance=20&mileage_max=&sort=best_match_desc&stock_type=all&year_max=&year_min=&zip='
    response = requests.get(website)
    soup = BeautifulSoup(response.content, 'html.parser')
    results = soup.find_all('div', {'class': 'vehicle-card'})
    for r in results:
        Custom.add(name, r.find('h2'))
        Custom.add(mileage, r.find('div', {'class':"mileage"}))
        Custom.add(rating_count, r.find('span', {'class': 'sds-rating__count'}))
        Custom.add(rating, r.find('span', {'class': 'sds-rating__link sds-button-link'}))
        Custom.add(price, r.find('span', {'class': 'primary-price'}))
        Custom.add(dealer_name, r.find('div', {'class': 'dealer-name'}))
        
data = pd.DataFrame({'Name': name,
                     'Milage': mileage,
                     'DealerName': dealer_name,
                     'Rating': rating,
                     'RatingCount': rating_count,
                     'Price': price})
data['Rating'] = data['Rating'].apply(lambda x: x.strip("(reviews) "))
data['Milage'] = data['Milage'].apply(lambda x: x.strip(" mi."))
data['Price'] = data['Price'].apply(lambda x: x.strip("$ "))

# %%
data.to_excel('data_crawled.xlsx', index=False)
